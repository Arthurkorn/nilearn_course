# %%
# %matplotlib inline

# %% [markdown]
# In this section, we will learn to extract signals in ROIs from fMRI data and compute a connectome with them.

# %% [markdown]
# # Extracting signal on a parcellation

# %% [markdown]
# ##### We are going to load the Harvard-Oxford atlas, in it's 'max-prob' version, ie the non probabilistic version:

# %%
from nilearn import datasets, plotting
atlas_img, labels = datasets.load_harvard_oxford('cort-maxprob-thr25-2mm')
plotting.plot_roi(atlas_img)

# %% [markdown]
# To extract signals on this atlas, we create an "Masker" object, that can transform niftis in time-series using a set of labels (the non-probabilistic atlas).

# %%
from nilearn.input_data import NiftiLabelsMasker
masker = NiftiLabelsMasker(labels_img=atlas_img)

# Now get the ADHD data
data = datasets.fetch_adhd(n_subjects=1)

# And apply the masker to the functional data
time_series = masker.fit_transform(data.func[0])

# %% [markdown]
# This take a little time. To avoid recomputing steps later, we can use the 'memory' argument of the masker. Also, to follow what's happening, we can use the 'verbose' argument.
#
# Now our 'time_series' should be a numpy array of shape: (time, n_labels)

# %%
time_series.shape
# Out:
# (152, 48)

# %% [markdown]
# We can plot these time-series using matplotlib:

# %%
from matplotlib import pyplot as plt
plot = plt.plot(time_series)

# %% [markdown]
# We can immediatly see that there an ROI-specific offset that is of little interest to us. Let's standardize time-series during extraction (center and norm them), with the "standardize" option of the masker:

# %%
masker = NiftiLabelsMasker(labels_img=atlas_img, standardize=True,
                           memory='/tmp/nilearn_course', verbose=5)

time_series = masker.fit_transform(data.func[0])
plot = plt.plot(time_series)
# Out:
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/usr/share/data/harvard-oxford-atlases/HarvardOxford/HarvardOxford-cort-maxprob-thr25-2mm.nii.gz')
# [NiftiLabelsMasker.fit_transform] loading images: /home/varoquau/nilearn_data/adhd/data/3902469/3902469_rest_tshift_RPI_voreg_mni.nii.gz
# [NiftiLabelsMasker.fit_transform] resampling images
# [Memory]    0.0s, 0.0min: Loading resample_img...
# ________________________________________resample_img cache loaded - 3.7s, 0.1min
# [NiftiLabelsMasker.fit_transform] extracting region signals
# [Memory]    1.8s, 0.0min: Loading img_to_signals_labels...
# _______________________________img_to_signals_labels cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] cleaning extracted signals
# [Memory]    0.0s, 0.0min: Loading clean...
# _______________________________________________clean cache loaded - 0.0s, 0.0min

# %% [markdown]
# We can now use numpy to plot a correlation matrix, which will be the correlation of the signals across ROIs

# %%
import numpy as np
correlation = np.corrcoef(time_series.T)
plt.figure(figsize=(10, 10))
plt.imshow(correlation, interpolation="nearest")
x_ticks = plt.xticks(range(len(labels) - 1), labels[1:], rotation=90)
y_ticks = plt.yticks(range(len(labels) - 1), labels[1:])

# %% [markdown]
# This is somewhat messy isn't it?
#
# What did we forget?

# %% [markdown]
# ## Improving the connectivity matrix

# %% [markdown]
# **Exercise**: Improve this connectivity matrix
#
# **Hint**: What in 'data.keys' can be used to improve the connectivity matrix? Look at the arguments of masker.fit_transform to find how to use it.

# %%
# %load adhd_connectivity.py

# %% [markdown]
# Better? Maybe, but one problem is that the atlas does not resolve functional structures.

# %% [markdown]
# # Extracting signal on a probabilistic atlas

# %% [markdown]
# We can use the MSDL atlas (Varoquaux, IPMI 2011), which is a probabilistic atlas: it is a set of weighted maps

# %%
atlas = datasets.fetch_msdl_atlas()
atlas_img = atlas['maps']
labels = atlas['labels']

# Plot the regions defining the default-mode network
import nibabel
atlas_img = nibabel.load(atlas_img)
display = plotting.plot_stat_map(nibabel.Nifti1Image(atlas_img.get_data()[..., 4],
                                                     atlas_img.get_affine()),
                        colorbar=False)
display.add_overlay(nibabel.Nifti1Image(atlas_img.get_data()[..., 5],
                                                     atlas_img.get_affine()),
                    cmap=plotting.cm.black_blue, vmax=.5, vmin=0)
display.add_overlay(nibabel.Nifti1Image(atlas_img.get_data()[..., 6],
                                                     atlas_img.get_affine()),
                    cmap=plotting.cm.black_green, vmax=.5, vmin=0)
display.add_overlay(nibabel.Nifti1Image(atlas_img.get_data()[..., 3],
                                                     atlas_img.get_affine()),
                    cmap=plotting.cm.black_pink, vmax=.5, vmin=0)

# %% [markdown]
# To extract time-series on such regions, "softly" defined by continuous maps, we should use nilearn.input_data.NiftiMapsMasker.
#
# **Excercise**: By analogy with the above, compute and display a correlation matrix on the MSDL atlas.
#
# **Note**: On nilearn 1.0 beta, it is not possible to retrieve correct labels for the MSDL atlas. This has been fixed in later versions.

# %%
# Solution
# %load adhd_msdl_connectivity.py

# %% [markdown]
# **Excercise** Compute the corresponding correlation matrix for a few other subjects in the ADHD dataset.

# %% [markdown]
# # Inverse covariance estimation

# %% [markdown]
# We can start by using the covariance estimators in scikit-learn

# %%
from sklearn import covariance
estimator = covariance.EmpiricalCovariance(store_precision=True)
estimator.fit(time_series)
plt.matshow(estimator.precision_)
plt.title('Non regularized inverse covariance')

# %% [markdown]
# **Excercise**: Now use covariance.GraphLassoCV to estimate a sparse inverse covariance.

# %% [markdown]
# Finally, give that we have multiple subjects, we can use the group-sparse model, to have better sparse recovery. For this we use the corresponding model in nilearn.covariance. It requires several time-series.

# %%
# Get the ADHD data for multiple subjects
data = datasets.fetch_adhd(n_subjects=4)

# And apply the masker to the functional data of each subject
time_series = list()
for subject_data, subject_confounds in zip(data.func, data.confounds):
     time_series.append(masker.fit_transform(subject_data, confounds=subject_confounds))

from nilearn.group_sparse_covariance import GroupSparseCovarianceCV
estimator = GroupSparseCovarianceCV()
estimator.fit(time_series)
for precision in estimator.precisions_.T:
    plt.matshow(precision)
# Out:
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/usr/share/data/harvard-oxford-atlases/HarvardOxford/HarvardOxford-cort-maxprob-thr25-2mm.nii.gz')
# [NiftiLabelsMasker.fit_transform] loading images: /home/varoquau/nilearn_data/adhd/data/3902469/3902469_rest_tshift_RPI_voreg_mni.nii.gz
# [NiftiLabelsMasker.fit_transform] resampling images
# [Memory]    0.0s, 0.0min: Loading resample_img...
# ________________________________________resample_img cache loaded - 2.2s, 0.0min
# [NiftiLabelsMasker.fit_transform] extracting region signals
# [Memory]    1.9s, 0.0min: Loading img_to_signals_labels...
# _______________________________img_to_signals_labels cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] cleaning extracted signals
# [Memory]    0.0s, 0.0min: Loading clean...
# _______________________________________________clean cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/usr/share/data/harvard-oxford-atlases/HarvardOxford/HarvardOxford-cort-maxprob-thr25-2mm.nii.gz')
# [NiftiLabelsMasker.fit_transform] loading images: /home/varoquau/nilearn_data/adhd/data/7774305/7774305_rest_tshift_RPI_voreg_mni.nii.gz
# [NiftiLabelsMasker.fit_transform] resampling images
# [Memory]    0.0s, 0.0min: Loading resample_img...
# ________________________________________resample_img cache loaded - 3.5s, 0.1min
# [NiftiLabelsMasker.fit_transform] extracting region signals
# [Memory]    1.8s, 0.0min: Loading img_to_signals_labels...
# _______________________________img_to_signals_labels cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] cleaning extracted signals
# [Memory]    0.0s, 0.0min: Loading clean...
# _______________________________________________clean cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/usr/share/data/harvard-oxford-atlases/HarvardOxford/HarvardOxford-cort-maxprob-thr25-2mm.nii.gz')
# [NiftiLabelsMasker.fit_transform] loading images: /home/varoquau/nilearn_data/adhd/data/3699991/3699991_rest_tshift_RPI_voreg_mni.nii.gz
# [NiftiLabelsMasker.fit_transform] resampling images
# [Memory]    0.0s, 0.0min: Loading resample_img...
# ________________________________________resample_img cache loaded - 4.0s, 0.1min
# [NiftiLabelsMasker.fit_transform] extracting region signals
# [Memory]    1.9s, 0.0min: Loading img_to_signals_labels...
# _______________________________img_to_signals_labels cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] cleaning extracted signals
# [Memory]    0.0s, 0.0min: Loading clean...
# _______________________________________________clean cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/usr/share/data/harvard-oxford-atlases/HarvardOxford/HarvardOxford-cort-maxprob-thr25-2mm.nii.gz')
# [NiftiLabelsMasker.fit_transform] loading images: /home/varoquau/nilearn_data/adhd/data/2014113/2014113_rest_tshift_RPI_voreg_mni.nii.gz
# [NiftiLabelsMasker.fit_transform] resampling images
# [Memory]    0.0s, 0.0min: Loading resample_img...
# ________________________________________resample_img cache loaded - 3.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] extracting region signals
# [Memory]    1.5s, 0.0min: Loading img_to_signals_labels...
# _______________________________img_to_signals_labels cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] cleaning extracted signals
# [Memory]    0.0s, 0.0min: Loading clean...
# _______________________________________________clean cache loaded - 0.0s, 0.0min
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] tolerance reached at iteration number 1: 1.356e-03
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 1.496e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 8.667e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 1.691e-01  ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 3
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 1.639e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 1.023e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 5.090e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (8 %) variation (max norm): 2.126e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 5 (10 %) variation (max norm): 1.231e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 6 (12 %) variation (max norm): 7.106e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 7 (14 %) variation (max norm): 4.504e-02  ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 7
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 0
# /home/varoquau/dev/scikit-learn/sklearn/cross_validation.py:1544: DeprecationWarning: check_cv will return indices instead of boolean masks from 0.17
#   'masks from 0.17', DeprecationWarning)
# /home/varoquau/dev/scikit-learn/sklearn/cross_validation.py:66: DeprecationWarning: The indices parameter is deprecated and will be removed (assumed True) in 0.17
#   stacklevel=1)
# /home/varoquau/dev/scikit-learn/sklearn/cross_validation.py:1544: DeprecationWarning: check_cv will return indices instead of boolean masks from 0.17
#   'masks from 0.17', DeprecationWarning)
# /home/varoquau/dev/scikit-learn/sklearn/cross_validation.py:66: DeprecationWarning: The indices parameter is deprecated and will be removed (assumed True) in 0.17
#   stacklevel=1)
# /home/varoquau/dev/scikit-learn/sklearn/cross_validation.py:1544: DeprecationWarning: check_cv will return indices instead of boolean masks from 0.17
#   'masks from 0.17', DeprecationWarning)
# /home/varoquau/dev/scikit-learn/sklearn/cross_validation.py:66: DeprecationWarning: The indices parameter is deprecated and will be removed (assumed True) in 0.17
#   stacklevel=1)
# /home/varoquau/dev/scikit-learn/sklearn/cross_validation.py:1544: DeprecationWarning: check_cv will return indices instead of boolean masks from 0.17
#   'masks from 0.17', DeprecationWarning)
# /home/varoquau/dev/scikit-learn/sklearn/cross_validation.py:66: DeprecationWarning: The indices parameter is deprecated and will be removed (assumed True) in 0.17
#   stacklevel=1)
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:    4.4s
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] tolerance reached at iteration number 1: 0.000e+00
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 1.639e+00  ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 1
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 1.512e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 1.105e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 5.015e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (8 %) variation (max norm): 2.634e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 5 (10 %) variation (max norm): 1.445e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 6 (12 %) variation (max norm): 7.913e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 7 (14 %) variation (max norm): 4.375e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 8 (16 %) variation (max norm): 3.071e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 9 (18 %) variation (max norm): 2.735e-02  ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 9
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 0
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] tolerance reached at iteration number 1: 0.000e+00
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 1.960e+00  ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 1
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 1.594e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 7.927e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 3.229e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (8 %) variation (max norm): 1.584e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 5 (10 %) variation (max norm): 9.351e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 6 (12 %) variation (max norm): 5.325e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 7 (14 %) variation (max norm): 2.829e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 8 (16 %) variation (max norm): 2.012e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 9 (18 %) variation (max norm): 1.815e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 10 (20 %) variation (max norm): 1.624e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 11 (22 %) variation (max norm): 1.339e-02  ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 11
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 0
# [GroupSparseCovarianceCV.fit] [GroupSparseCovarianceCV] Done refinement  1 out of 4
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 2.674e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 1.345e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 5.698e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (8 %) variation (max norm): 1.881e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 5 (10 %) variation (max norm): 1.692e-01  ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 5
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 6.679e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 4.218e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 1.894e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (8 %) variation (max norm): 7.204e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 5 (10 %) variation (max norm): 3.860e-02  ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 5
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 5.260e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 3.858e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 2.266e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (8 %) variation (max norm): 1.299e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 5 (10 %) variation (max norm): 8.271e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 6 (12 %) variation (max norm): 5.286e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 7 (14 %) variation (max norm): 3.320e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 8 (16 %) variation (max norm): 2.252e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 9 (18 %) variation (max norm): 1.616e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 10 (20 %) variation (max norm): 1.148e-02  ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 10
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 0
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   15.0s finished
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:    9.0s
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 3.434e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 1.600e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 8.935e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (8 %) variation (max norm): 1.595e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 5 (10 %) variation (max norm): 1.319e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 6 (12 %) variation (max norm): 1.011e-01  ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 6
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 6.263e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 4.928e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 2.052e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (8 %) variation (max norm): 8.720e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 5 (10 %) variation (max norm): 5.005e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 6 (12 %) variation (max norm): 2.790e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 7 (14 %) variation (max norm): 1.405e-02  ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 7
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 0
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 0
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 3.723e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 1.633e+00  ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 2
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 6.413e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 3.405e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 1.044e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (8 %) variation (max norm): 6.280e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 5 (10 %) variation (max norm): 2.607e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 6 (12 %) variation (max norm): 1.647e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 7 (14 %) variation (max norm): 1.515e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 8 (16 %) variation (max norm): 1.169e-02  ...
# [GroupSparseCovarianceCV.fit] tolerance reached at iteration number 9: 7.831e-03
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 4.665e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 3.689e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 1.933e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (8 %) variation (max norm): 1.206e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 5 (10 %) variation (max norm): 7.537e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 6 (12 %) variation (max norm): 4.666e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 7 (14 %) variation (max norm): 3.216e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 8 (16 %) variation (max norm): 2.227e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 9 (18 %) variation (max norm): 1.524e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 10 (20 %) variation (max norm): 1.063e-02  ...
# [GroupSparseCovarianceCV.fit] tolerance reached at iteration number 11: 7.605e-03
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 0
# [GroupSparseCovarianceCV.fit] [GroupSparseCovarianceCV] Done refinement  2 out of 4
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 3.920e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 1.746e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 1.055e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (8 %) variation (max norm): 3.756e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 5 (10 %) variation (max norm): 1.876e-01  ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 5
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 1.470e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 1.141e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 6.440e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (8 %) variation (max norm): 3.764e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 5 (10 %) variation (max norm): 3.033e-02  ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 5
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 0
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 0
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   24.4s finished
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:    5.2s
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 4.924e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 1.811e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 1.423e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (8 %) variation (max norm): 5.627e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 5 (10 %) variation (max norm): 1.887e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 6 (12 %) variation (max norm): 1.211e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 7 (14 %) variation (max norm): 8.614e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 8 (16 %) variation (max norm): 7.912e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 9 (18 %) variation (max norm): 6.999e-02  ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 9
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 0
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 0
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 0
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 5.106e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 1.413e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 1.552e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (8 %) variation (max norm): 5.112e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 5 (10 %) variation (max norm): 1.384e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 6 (12 %) variation (max norm): 7.030e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 7 (14 %) variation (max norm): 6.582e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 8 (16 %) variation (max norm): 4.352e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 9 (18 %) variation (max norm): 3.484e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 10 (20 %) variation (max norm): 2.369e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 11 (22 %) variation (max norm): 1.447e-02  ...
# [GroupSparseCovarianceCV.fit] tolerance reached at iteration number 12: 9.341e-03
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 1.096e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 7.474e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 3.421e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (8 %) variation (max norm): 1.793e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 5 (10 %) variation (max norm): 1.113e-02  ...
# [GroupSparseCovarianceCV.fit] tolerance reached at iteration number 6: 6.822e-03
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 0
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 0
# [GroupSparseCovarianceCV.fit] [GroupSparseCovarianceCV] Done refinement  3 out of 4
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 3.824e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 1.704e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 1.050e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (8 %) variation (max norm): 3.761e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 5 (10 %) variation (max norm): 1.811e-01  ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 5
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 9.382e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 7.464e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 5.691e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (8 %) variation (max norm): 4.323e-02  ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 4
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 5.782e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 3.297e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 1.588e-02  ...
# [GroupSparseCovarianceCV.fit] tolerance reached at iteration number 4: 8.365e-03
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 4.935e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 3.662e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 1.871e-02  ...
# [GroupSparseCovarianceCV.fit] tolerance reached at iteration number 4: 8.632e-03
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   18.5s finished
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:    6.3s
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 4.810e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 1.770e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 1.418e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (8 %) variation (max norm): 5.300e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 5 (10 %) variation (max norm): 1.728e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 6 (12 %) variation (max norm): 1.160e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 7 (14 %) variation (max norm): 8.053e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 8 (16 %) variation (max norm): 8.111e-02  ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 8
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 4.630e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 3.298e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 1.547e-02  ...
# [GroupSparseCovarianceCV.fit] tolerance reached at iteration number 4: 9.141e-03
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 5.534e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 3.986e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 2.044e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (8 %) variation (max norm): 1.098e-02  ...
# [GroupSparseCovarianceCV.fit] tolerance reached at iteration number 5: 5.470e-03
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 5.227e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 4.118e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 1.970e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (8 %) variation (max norm): 1.060e-02  ...
# [GroupSparseCovarianceCV.fit] tolerance reached at iteration number 5: 5.441e-03
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 5.002e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 1.387e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 1.516e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (8 %) variation (max norm): 4.481e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 5 (10 %) variation (max norm): 1.236e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 6 (12 %) variation (max norm): 6.766e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 7 (14 %) variation (max norm): 6.058e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 8 (16 %) variation (max norm): 4.344e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 9 (18 %) variation (max norm): 3.249e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 10 (20 %) variation (max norm): 2.087e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 11 (22 %) variation (max norm): 1.218e-02  ...
# [GroupSparseCovarianceCV.fit] tolerance reached at iteration number 12: 6.760e-03
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 4.863e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 3.003e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 1.169e-02  ...
# [GroupSparseCovarianceCV.fit] tolerance reached at iteration number 4: 6.624e-03
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 4.616e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 3.206e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 1.346e-02  ...
# [GroupSparseCovarianceCV.fit] tolerance reached at iteration number 4: 6.765e-03
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 4.565e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 3.202e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 1.416e-02  ...
# [GroupSparseCovarianceCV.fit] tolerance reached at iteration number 4: 7.294e-03
# [GroupSparseCovarianceCV.fit] [GroupSparseCovarianceCV] Done refinement  4 out of 4
# [GroupSparseCovarianceCV.fit] Final optimization
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (1 %) variation (max norm): 4.025e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (2 %) variation (max norm): 1.686e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (3 %) variation (max norm): 1.108e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (4 %) variation (max norm): 3.559e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 5 (5 %) variation (max norm): 1.513e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 6 (6 %) variation (max norm): 1.065e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 7 (7 %) variation (max norm): 9.145e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 8 (8 %) variation (max norm): 7.872e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 9 (9 %) variation (max norm): 5.834e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 10 (10 %) variation (max norm): 3.885e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 11 (11 %) variation (max norm): 2.415e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 12 (12 %) variation (max norm): 1.413e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 13 (13 %) variation (max norm): 9.013e-03  ...
# [GroupSparseCovarianceCV.fit] * iteration 14 (14 %) variation (max norm): 5.774e-03  ...
# [GroupSparseCovarianceCV.fit] * iteration 15 (15 %) variation (max norm): 3.550e-03  ...
# [GroupSparseCovarianceCV.fit] * iteration 16 (16 %) variation (max norm): 1.986e-03  ...
# [GroupSparseCovarianceCV.fit] * iteration 17 (17 %) variation (max norm): 1.092e-03  ...
# [GroupSparseCovarianceCV.fit] tolerance reached at iteration number 18: 8.372e-04
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   22.7s finished

# %%
estimator.precisions_.shape
# Out:
# (48, 48, 4)
