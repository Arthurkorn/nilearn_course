# %%
# %matplotlib inline

# %% [markdown]
# In this section, we will learn to extract signals in ROIs from fMRI data and compute a connectome with them.

# %% [markdown]
# # Extracting signal on a parcellation

# %% [markdown]
# ##### We are going to load the Harvard-Oxford atlas, in it's 'max-prob' version, ie the non probabilistic version:

# %%
from nilearn import datasets, plotting
atlas_img, labels = datasets.load_harvard_oxford('cort-maxprob-thr25-2mm')
plotting.plot_roi(atlas_img)

# %% [markdown]
# To extract signals on this atlas, we create an "Masker" object, that can transform niftis in time-series using a set of labels (the non-probabilistic atlas).

# %%
from nilearn.input_data import NiftiLabelsMasker
masker = NiftiLabelsMasker(labels_img=atlas_img)

# Now get the ADHD data
data = datasets.fetch_adhd(n_subjects=1)

# And apply the masker to the functional data
time_series = masker.fit_transform(data.func[0])

# %% [markdown]
# This take a little time. To avoid recomputing steps later, we can use the 'memory' argument of the masker. Also, to follow what's happening, we can use the 'verbose' argument.
#
# Now our 'time_series' should be a numpy array of shape: (time, n_labels)

# %%
time_series.shape
# Out:
# (152, 48)

# %% [markdown]
# We can plot these time-series using matplotlib:

# %%
from matplotlib import pyplot as plt
plot = plt.plot(time_series)

# %% [markdown]
# We can immediatly see that there an ROI-specific offset that is of little interest to us. Let's standardize time-series during extraction (center and norm them), with the "standardize" option of the masker:

# %%
masker = NiftiLabelsMasker(labels_img=atlas_img, standardize=True,
                           memory='/tmp/nilearn_course', verbose=5)

time_series = masker.fit_transform(data.func[0])
plot = plt.plot(time_series)
# Out:
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/usr/share/data/harvard-oxford-atlases/HarvardOxford/HarvardOxford-cort-maxprob-thr25-2mm.nii.gz')
# [NiftiLabelsMasker.fit_transform] loading images: /home/varoquau/nilearn_data/adhd/data/3902469/3902469_rest_tshift_RPI_voreg_mni.nii.gz
# [NiftiLabelsMasker.fit_transform] resampling images
# [Memory]    0.0s, 0.0min: Loading resample_img...
# ________________________________________resample_img cache loaded - 3.6s, 0.1min
# [NiftiLabelsMasker.fit_transform] extracting region signals
# [Memory]    1.8s, 0.0min: Loading img_to_signals_labels...
# _______________________________img_to_signals_labels cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] cleaning extracted signals
# [Memory]    0.0s, 0.0min: Loading clean...
# _______________________________________________clean cache loaded - 0.0s, 0.0min

# %% [markdown]
# We can now use numpy to plot a correlation matrix, which will be the correlation of the signals across ROIs

# %%
import numpy as np
correlation = np.corrcoef(time_series.T)
plt.figure(figsize=(10, 10))
plt.imshow(correlation, interpolation="nearest")
x_ticks = plt.xticks(range(len(labels) - 1), labels[1:], rotation=90)
y_ticks = plt.yticks(range(len(labels) - 1), labels[1:])

# %% [markdown]
# This is somewhat messy isn't it?
#
# What did we forget?

# %% [markdown]
# ## Improving the connectivity matrix

# %% [markdown]
# **Exercise**: Improve this connectivity matrix
#
# **Hint**: What in 'data.keys' can be used to improve the connectivity matrix? Look at the arguments of masker.fit_transform to find how to use it.

# %%
# %load adhd_connectivity.py

# %%
from nilearn import datasets
atlas_img, labels = datasets.load_harvard_oxford('cort-maxprob-thr25-2mm')

from nilearn.input_data import NiftiLabelsMasker

masker = NiftiLabelsMasker(labels_img=atlas_img, standardize=True,
                           memory='/tmp/nilearn_course', verbose=5)

from matplotlib import pyplot as plt
data = datasets.fetch_adhd(n_subjects=1)

time_series = masker.fit_transform(data.func[0],
                                   confounds=data.confounds)

import numpy as np
correlation = np.corrcoef(time_series.T)
plt.figure(figsize=(10, 10))
plt.imshow(correlation, interpolation="nearest")
x_ticks = plt.xticks(range(len(labels) - 1), labels[1:], rotation=90)
y_ticks = plt.yticks(range(len(labels) - 1), labels[1:])
# Out:
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/usr/share/data/harvard-oxford-atlases/HarvardOxford/HarvardOxford-cort-maxprob-thr25-2mm.nii.gz')
# [NiftiLabelsMasker.fit_transform] loading images: /home/varoquau/nilearn_data/adhd/data/3902469/3902469_rest_tshift_RPI_voreg_mni.nii.gz
# [NiftiLabelsMasker.fit_transform] resampling images
# [Memory]    0.0s, 0.0min: Loading resample_img...
# ________________________________________resample_img cache loaded - 3.4s, 0.1min
# [NiftiLabelsMasker.fit_transform] extracting region signals
# [Memory]    1.8s, 0.0min: Loading img_to_signals_labels...
# _______________________________img_to_signals_labels cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] cleaning extracted signals
# [Memory]    0.0s, 0.0min: Loading clean...
# _______________________________________________clean cache loaded - 0.0s, 0.0min

# %% [markdown]
# Better? Maybe, but one problem is that the atlas does not resolve functional structures.

# %% [markdown]
# # Extracting signal on a probabilistic atlas

# %% [markdown]
# We can use the MSDL atlas (Varoquaux, IPMI 2011), which is a probabilistic atlas: it is a set of weighted maps

# %%
atlas = datasets.fetch_msdl_atlas()
atlas_img = atlas['maps']
labels = atlas['labels']

# Plot the regions defining the default-mode network
import nibabel
atlas_img = nibabel.load(atlas_img)
display = plotting.plot_stat_map(nibabel.Nifti1Image(atlas_img.get_data()[..., 4],
                                                     atlas_img.get_affine()),
                        colorbar=False)
display.add_overlay(nibabel.Nifti1Image(atlas_img.get_data()[..., 5],
                                                     atlas_img.get_affine()),
                    cmap=plotting.cm.black_blue, vmax=.5, vmin=0)
display.add_overlay(nibabel.Nifti1Image(atlas_img.get_data()[..., 6],
                                                     atlas_img.get_affine()),
                    cmap=plotting.cm.black_green, vmax=.5, vmin=0)
display.add_overlay(nibabel.Nifti1Image(atlas_img.get_data()[..., 3],
                                                     atlas_img.get_affine()),
                    cmap=plotting.cm.black_pink, vmax=.5, vmin=0)

# %% [markdown]
# To extract time-series on such regions, "softly" defined by continuous maps, we should use nilearn.input_data.NiftiMapsMasker.
#
# **Excercise**: By analogy with the above, compute and display a correlation matrix on the MSDL atlas.
#
# **Note**: On nilearn 1.0 beta, it is not possible to retrieve correct labels for the MSDL atlas. This has been fixed in later versions.

# %%
# Solution
# %load adhd_msdl_connectivity.py

# %%
from nilearn import datasets
atlas = datasets.fetch_msdl_atlas()
atlas_img = atlas['maps']
import pandas
labels = pandas.read_csv(atlas['labels'])['name']

from nilearn.input_data import NiftiMapsMasker

masker = NiftiMapsMasker(maps_img=atlas_img, standardize=True,
                           memory='/tmp/nilearn_course', verbose=5)

from matplotlib import pyplot as plt
data = datasets.fetch_adhd(n_subjects=1)

time_series = masker.fit_transform(data.func[0],
                                   confounds=data.confounds)

import numpy as np
correlation = np.corrcoef(time_series.T)
plt.figure(figsize=(10, 10))
plt.imshow(correlation, interpolation="nearest")
x_ticks = plt.xticks(range(len(labels)), labels, rotation=90)
y_ticks = plt.yticks(range(len(labels)), labels)
# Out:
# [NiftiMapsMasker.fit_transform] loading regions from /home/varoquau/nilearn_data/msdl_atlas/MSDL_rois/msdl_rois.nii
# [NiftiMapsMasker.fit_transform] loading images from /home/varoquau/nilearn_data/adhd/data/3902469/3902469_rest_tshift_RPI_voreg_mni.nii.gz
# [NiftiMapsMasker.fit_transform] resampling images to fit maps
# [Memory]    0.0s, 0.0min: Loading resample_img...
# ________________________________________resample_img cache loaded - 0.1s, 0.0min
# [NiftiMapsMasker.fit_transform] extracting region signals
# [Memory]    0.1s, 0.0min: Loading img_to_signals_maps...
# _________________________________img_to_signals_maps cache loaded - 0.0s, 0.0min
# [NiftiMapsMasker.fit_transform] cleaning extracted signals
# [Memory]    0.0s, 0.0min: Loading clean...
# _______________________________________________clean cache loaded - 0.0s, 0.0min
# /home/varoquau/dev/nilearn/nilearn/_utils/cache_mixin.py:206: UserWarning: memory_level is currently set to 0 but a Memory object has been provided. Setting memory_level to 1.
#   warnings.warn("memory_level is currently set to 0 but "

# %% [markdown]
# **Excercise** Compute the corresponding correlation matrix for a few other subjects in the ADHD dataset.

# %% [markdown]
# # Inverse covariance estimation

# %% [markdown]
# We can start by using the covariance estimators in scikit-learn

# %%
from sklearn import covariance
estimator = covariance.EmpiricalCovariance(store_precision=True)
estimator.fit(time_series)
plt.matshow(estimator.precision_)
plt.title('Non regularized inverse covariance')

# %% [markdown]
# **Excercise**: Now use covariance.GraphLassoCV to estimate a sparse inverse covariance.

# %% [markdown]
# Finally, give that we have multiple subjects, we can use the group-sparse model, to have better sparse recovery. For this we use the corresponding model in nilearn.covariance. It requires several time-series.

# %%
# Get the ADHD data for multiple subjects
data = datasets.fetch_adhd(n_subjects=4)

# And apply the masker to the functional data of each subject
time_series = list()
for subject_data, subject_confounds in zip(data.func, data.confounds):
     time_series.append(masker.fit_transform(subject_data, confounds=subject_confounds))

from nilearn.group_sparse_covariance import GroupSparseCovarianceCV
estimator = GroupSparseCovarianceCV()
estimator.fit(time_series)
for precision in estimator.precisions_.T:
    plt.matshow(precision)
# Out:
# [NiftiMapsMasker.fit_transform] loading regions from /home/varoquau/nilearn_data/msdl_atlas/MSDL_rois/msdl_rois.nii
# [NiftiMapsMasker.fit_transform] loading images from /home/varoquau/nilearn_data/adhd/data/3902469/3902469_rest_tshift_RPI_voreg_mni.nii.gz
# [NiftiMapsMasker.fit_transform] resampling images to fit maps
# [Memory]    0.0s, 0.0min: Loading resample_img...
# ________________________________________resample_img cache loaded - 0.0s, 0.0min
# [NiftiMapsMasker.fit_transform] extracting region signals
# [Memory]    0.1s, 0.0min: Loading img_to_signals_maps...
# _________________________________img_to_signals_maps cache loaded - 0.0s, 0.0min
# [NiftiMapsMasker.fit_transform] cleaning extracted signals
# [Memory]    0.0s, 0.0min: Loading clean...
# _______________________________________________clean cache loaded - 0.0s, 0.0min
# [NiftiMapsMasker.fit_transform] loading regions from /home/varoquau/nilearn_data/msdl_atlas/MSDL_rois/msdl_rois.nii
# [NiftiMapsMasker.fit_transform] loading images from /home/varoquau/nilearn_data/adhd/data/7774305/7774305_rest_tshift_RPI_voreg_mni.nii.gz
# [NiftiMapsMasker.fit_transform] resampling images to fit maps
# [Memory]    0.0s, 0.0min: Loading resample_img...
# ________________________________________resample_img cache loaded - 0.2s, 0.0min
# [NiftiMapsMasker.fit_transform] extracting region signals
# [Memory]    0.1s, 0.0min: Loading img_to_signals_maps...
# _________________________________img_to_signals_maps cache loaded - 0.0s, 0.0min
# [NiftiMapsMasker.fit_transform] cleaning extracted signals
# [Memory]    0.0s, 0.0min: Loading clean...
# _______________________________________________clean cache loaded - 0.0s, 0.0min
# [NiftiMapsMasker.fit_transform] loading regions from /home/varoquau/nilearn_data/msdl_atlas/MSDL_rois/msdl_rois.nii
# [NiftiMapsMasker.fit_transform] loading images from /home/varoquau/nilearn_data/adhd/data/3699991/3699991_rest_tshift_RPI_voreg_mni.nii.gz
# [NiftiMapsMasker.fit_transform] resampling images to fit maps
# [Memory]    0.0s, 0.0min: Loading resample_img...
# ________________________________________resample_img cache loaded - 0.2s, 0.0min
# [NiftiMapsMasker.fit_transform] extracting region signals
# [Memory]    0.1s, 0.0min: Loading img_to_signals_maps...
# _________________________________img_to_signals_maps cache loaded - 0.0s, 0.0min
# [NiftiMapsMasker.fit_transform] cleaning extracted signals
# [Memory]    0.0s, 0.0min: Loading clean...
# _______________________________________________clean cache loaded - 0.0s, 0.0min
# [NiftiMapsMasker.fit_transform] loading regions from /home/varoquau/nilearn_data/msdl_atlas/MSDL_rois/msdl_rois.nii
# [NiftiMapsMasker.fit_transform] loading images from /home/varoquau/nilearn_data/adhd/data/2014113/2014113_rest_tshift_RPI_voreg_mni.nii.gz
# [NiftiMapsMasker.fit_transform] resampling images to fit maps
# [Memory]    0.0s, 0.0min: Loading resample_img...
# ________________________________________resample_img cache loaded - 0.2s, 0.0min
# [NiftiMapsMasker.fit_transform] extracting region signals
# [Memory]    0.1s, 0.0min: Loading img_to_signals_maps...
# _________________________________img_to_signals_maps cache loaded - 0.0s, 0.0min
# [NiftiMapsMasker.fit_transform] cleaning extracted signals
# [Memory]    0.0s, 0.0min: Loading clean...
# _______________________________________________clean cache loaded - 0.0s, 0.0min
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] tolerance reached at iteration number 1: 0.000e+00
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 1.633e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 8.563e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 8.870e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (8 %) variation (max norm): 4.242e-02  ...
# [GroupSparseCovarianceCV.fit] tolerance reached at iteration number 5: 9.172e-03
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 1.249e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 6.502e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 3.526e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (8 %) variation (max norm): 1.928e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 5 (10 %) variation (max norm): 1.101e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 6 (12 %) variation (max norm): 6.216e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 7 (14 %) variation (max norm): 2.773e-02  ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 7
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 0
# /home/varoquau/dev/scikit-learn/sklearn/cross_validation.py:1544: DeprecationWarning: check_cv will return indices instead of boolean masks from 0.17
#   'masks from 0.17', DeprecationWarning)
# /home/varoquau/dev/scikit-learn/sklearn/cross_validation.py:66: DeprecationWarning: The indices parameter is deprecated and will be removed (assumed True) in 0.17
#   stacklevel=1)
# /home/varoquau/dev/scikit-learn/sklearn/cross_validation.py:1544: DeprecationWarning: check_cv will return indices instead of boolean masks from 0.17
#   'masks from 0.17', DeprecationWarning)
# /home/varoquau/dev/scikit-learn/sklearn/cross_validation.py:66: DeprecationWarning: The indices parameter is deprecated and will be removed (assumed True) in 0.17
#   stacklevel=1)
# /home/varoquau/dev/scikit-learn/sklearn/cross_validation.py:1544: DeprecationWarning: check_cv will return indices instead of boolean masks from 0.17
#   'masks from 0.17', DeprecationWarning)
# /home/varoquau/dev/scikit-learn/sklearn/cross_validation.py:66: DeprecationWarning: The indices parameter is deprecated and will be removed (assumed True) in 0.17
#   stacklevel=1)
# /home/varoquau/dev/scikit-learn/sklearn/cross_validation.py:1544: DeprecationWarning: check_cv will return indices instead of boolean masks from 0.17
#   'masks from 0.17', DeprecationWarning)
# /home/varoquau/dev/scikit-learn/sklearn/cross_validation.py:66: DeprecationWarning: The indices parameter is deprecated and will be removed (assumed True) in 0.17
#   stacklevel=1)
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:    2.9s
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 1.809e-02  ...
# [GroupSparseCovarianceCV.fit] tolerance reached at iteration number 2: 8.830e-08
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 2.129e+00  ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 1
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 1.387e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 7.178e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 2.812e-01  ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 3
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 0
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 2.646e-02  ...
# [GroupSparseCovarianceCV.fit] tolerance reached at iteration number 2: 4.187e-07
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 1.501e+00  ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 1
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 1.354e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 6.040e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 2.791e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (8 %) variation (max norm): 1.560e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 5 (10 %) variation (max norm): 8.473e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 6 (12 %) variation (max norm): 4.967e-02  ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 6
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 0
# [GroupSparseCovarianceCV.fit] [GroupSparseCovarianceCV] Done refinement  1 out of 4
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 2.890e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 8.746e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 7.395e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (8 %) variation (max norm): 1.425e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 5 (10 %) variation (max norm): 8.567e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 6 (12 %) variation (max norm): 6.892e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 7 (14 %) variation (max norm): 2.019e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 8 (16 %) variation (max norm): 1.064e-02  ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 8
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 5.301e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 2.934e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 1.400e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (8 %) variation (max norm): 6.502e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 5 (10 %) variation (max norm): 3.419e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 6 (12 %) variation (max norm): 1.400e-02  ...
# [GroupSparseCovarianceCV.fit] tolerance reached at iteration number 7: 6.400e-03
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 0
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 0
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    7.0s finished
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:    3.5s
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 3.621e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 1.303e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 9.474e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (8 %) variation (max norm): 1.746e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 5 (10 %) variation (max norm): 1.683e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 6 (12 %) variation (max norm): 1.564e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 7 (14 %) variation (max norm): 5.397e-02  ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 7
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 4.880e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 3.398e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 1.331e-01  ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 3
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 0
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 0
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 2.658e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 9.444e-01  ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 2
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 5.457e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 3.256e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 1.211e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (8 %) variation (max norm): 6.369e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 5 (10 %) variation (max norm): 3.145e-02  ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 5
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 0
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 0
# [GroupSparseCovarianceCV.fit] [GroupSparseCovarianceCV] Done refinement  2 out of 4
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 3.185e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 7.821e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 8.086e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (8 %) variation (max norm): 2.963e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 5 (10 %) variation (max norm): 9.914e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 6 (12 %) variation (max norm): 8.247e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 7 (14 %) variation (max norm): 5.067e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 8 (16 %) variation (max norm): 1.582e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 9 (18 %) variation (max norm): 1.093e-02  ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 9
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 1.790e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 8.869e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 3.541e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (8 %) variation (max norm): 1.507e-02  ...
# [GroupSparseCovarianceCV.fit] tolerance reached at iteration number 5: 7.165e-03
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 1.658e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 9.621e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 4.419e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (8 %) variation (max norm): 1.858e-02  ...
# [GroupSparseCovarianceCV.fit] tolerance reached at iteration number 5: 8.812e-03
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 1.586e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 9.969e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 5.595e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (8 %) variation (max norm): 2.547e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 5 (10 %) variation (max norm): 1.182e-02  ...
# [GroupSparseCovarianceCV.fit] tolerance reached at iteration number 6: 6.285e-03
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    8.5s finished
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:    5.0s
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 3.954e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 1.112e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 1.102e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (8 %) variation (max norm): 3.598e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 5 (10 %) variation (max norm): 1.555e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 6 (12 %) variation (max norm): 1.861e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 7 (14 %) variation (max norm): 1.164e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 8 (16 %) variation (max norm): 3.558e-02  ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 8
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 1.611e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 1.119e-01  ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 2
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 1.499e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 1.058e-01  ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 2
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 0
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 2.940e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 8.085e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 7.280e-01  ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 3
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 2.220e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 1.475e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 3.852e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (8 %) variation (max norm): 1.805e-02  ...
# [GroupSparseCovarianceCV.fit] tolerance reached at iteration number 5: 9.363e-03
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 1.432e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 8.443e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 3.734e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (8 %) variation (max norm): 1.856e-02  ...
# [GroupSparseCovarianceCV.fit] tolerance reached at iteration number 5: 9.148e-03
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 1.345e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 9.605e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 4.056e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (8 %) variation (max norm): 2.236e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 5 (10 %) variation (max norm): 1.355e-02  ...
# [GroupSparseCovarianceCV.fit] tolerance reached at iteration number 6: 6.996e-03
# [GroupSparseCovarianceCV.fit] [GroupSparseCovarianceCV] Done refinement  3 out of 4
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 3.713e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 8.406e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 7.672e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (8 %) variation (max norm): 5.003e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 5 (10 %) variation (max norm): 2.257e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 6 (12 %) variation (max norm): 8.514e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 7 (14 %) variation (max norm): 4.502e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 8 (16 %) variation (max norm): 5.312e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 9 (18 %) variation (max norm): 3.827e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 10 (20 %) variation (max norm): 2.002e-02  ...
# [GroupSparseCovarianceCV.fit] tolerance reached at iteration number 11: 9.496e-03
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 3.342e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 2.656e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 1.417e-02  ...
# [GroupSparseCovarianceCV.fit] tolerance reached at iteration number 4: 5.888e-03
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 3.467e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 2.094e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 1.056e-02  ...
# [GroupSparseCovarianceCV.fit] tolerance reached at iteration number 4: 4.644e-03
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 3.429e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 2.111e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 1.150e-02  ...
# [GroupSparseCovarianceCV.fit] tolerance reached at iteration number 4: 4.989e-03
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   12.0s finished
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:    4.9s
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 4.503e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 8.094e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 1.130e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (8 %) variation (max norm): 7.422e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 5 (10 %) variation (max norm): 2.481e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 6 (12 %) variation (max norm): 1.337e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 7 (14 %) variation (max norm): 1.538e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 8 (16 %) variation (max norm): 1.334e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 9 (18 %) variation (max norm): 7.805e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 10 (20 %) variation (max norm): 2.810e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 11 (22 %) variation (max norm): 1.315e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 12 (24 %) variation (max norm): 1.077e-02  ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 12
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 2.784e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 2.419e-02  ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 2
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 0
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 0
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 3.451e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 7.014e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 8.687e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (8 %) variation (max norm): 3.871e-01  ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 4
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 0
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (2 %) variation (max norm): 1.100e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (4 %) variation (max norm): 7.157e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (6 %) variation (max norm): 2.883e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (8 %) variation (max norm): 1.389e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 5 (10 %) variation (max norm): 1.071e-02  ...
# [GroupSparseCovarianceCV.fit] tolerance reached at iteration number 6: 7.184e-03
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] Log-likelihood on test set is decreasing. Stopping at iteration 0
# [GroupSparseCovarianceCV.fit] [GroupSparseCovarianceCV] Done refinement  4 out of 4
# [GroupSparseCovarianceCV.fit] Final optimization
# [GroupSparseCovarianceCV.fit] * iteration 0 (0 %) ...
# [GroupSparseCovarianceCV.fit] * iteration 1 (1 %) variation (max norm): 3.807e+00  ...
# [GroupSparseCovarianceCV.fit] * iteration 2 (2 %) variation (max norm): 6.483e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 3 (3 %) variation (max norm): 9.039e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 4 (4 %) variation (max norm): 5.153e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 5 (5 %) variation (max norm): 1.710e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 6 (6 %) variation (max norm): 1.183e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 7 (7 %) variation (max norm): 1.067e-01  ...
# [GroupSparseCovarianceCV.fit] * iteration 8 (8 %) variation (max norm): 7.157e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 9 (9 %) variation (max norm): 3.299e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 10 (10 %) variation (max norm): 1.130e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 11 (11 %) variation (max norm): 1.030e-02  ...
# [GroupSparseCovarianceCV.fit] * iteration 12 (12 %) variation (max norm): 7.293e-03  ...
# [GroupSparseCovarianceCV.fit] * iteration 13 (13 %) variation (max norm): 5.684e-03  ...
# [GroupSparseCovarianceCV.fit] * iteration 14 (14 %) variation (max norm): 3.892e-03  ...
# [GroupSparseCovarianceCV.fit] * iteration 15 (15 %) variation (max norm): 2.100e-03  ...
# [GroupSparseCovarianceCV.fit] tolerance reached at iteration number 16: 8.182e-04
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   11.6s finished

# %%
estimator.precisions_.shape
# Out:
# (39, 39, 4)
